# %% [markdown]
# # Labeling (Rule-based + Isolation Forest)
#
# **Goal** Create y labels for high-cost detecton:
# -y_rule (transparent, programatic rules)
# -y_iforest (unsupervised labeling approach)
# -y_final (consensus options)
#
# **Input** ../data/preprocessed/beneficiary_features.csv
# **Output** ../data/preprocessed/beneficiary_labeled.csv

# %%
import pandas as pd
import numpy as np

FEATURE_PATH = '../data/processed/beneficiary_features'
df = pd.read_csv(FEATURE_PATH)

print(df.shape)
df.head(3)
df.columns
# Out:
# (349064, 45)
# Index(['Beneficiary Code', 'Birth_date', 'Date_of_Death', 'Gender', 'Race',
#        'End_Stage_Renal_Disease_Indicator', 'State_code', 'County_code',
#        'Number_of_months_covered_a', 'Numver_of_months_covered_b',
#        'Number_of_months_HMO_coverage', 'Number_of_months_covered_d',
#        'Alzhiemers_or_senile', 'Heart_Failure', 'Chronic_Kidney', 'Cancer',
#        'COPD', 'Depression', 'Diabetes', 'ischemic_Heart_Disease',
#        'Osteoporosis', 'Rheumatoid_Arthritis', 'Stroke', 'IP_reimbursement',
#        'IP_Bene_Amount', 'IP_primary_payer_reimbursement',
#        'OP_medicare_reimbursement', 'OP_bene_resp_amount', 'OP_primary',
#        'Carrier_medicare_reimb', 'Carrier_bene_amount',
#        'Carrier_annual_payer_reimb', 'AGE', 'total_reimbursement',
#        'total_beneficiary_amount', 'total_primary_payment',
#        'total_coverage_months', 'chronic_count', 'avg_reimb', 'op_ratio',
#        'car_ratio', 'high_chronic_flag', 'high_reimb_flag', 'hmo_covered_flag',
#        'dual_elig_flag'],
#       dtype='object')

# %%
#Columns needed for labeling

needed = [
    'AGE','Date_of_Death', 'Gender', 'Race', 'total_coverage_months', 'chronic_count',
    'avg_reimb', 'op_ratio','car_ratio', 'Number_of_months_covered_a', 'Numver_of_months_covered_b',
       'Number_of_months_HMO_coverage', 'Number_of_months_covered_d',
]

present = [c for c in needed if c in df.columns]
w = df[present].copy()

#Clean ratios/numerics
for c in ["avg_reimb", "op_ratio", "car_ratio"]:
    if c in w:
        w[c] = pd.to_numeric(w[c], errors="coerce").replace([np.inf, -np.inf], np.nan)

for c in w.select_dtypes(include=[np.number]).columns:
    w[c] = w[c].fillna(w[c].median())

w.head(3)
# Out:
#    AGE  Date_of_Death  Gender      Race  total_coverage_months  chronic_count  \
# 0   51              0  Female  Hispanic                     24             13
# 1   51              0  Female     White                     36             15
# 2   51              0    Male     White                     48             13
#
#      avg_reimb  op_ratio  car_ratio  Number_of_months_covered_a  \
# 0  3551.200000  0.018765   0.075859                          12
# 1   509.459459  0.132720   0.254976                          12
# 2   798.775510  0.002667   0.040956                          12
#
#    Numver_of_months_covered_b  Number_of_months_HMO_coverage  \
# 0                          12                              0
# 1                          12                              0
# 2                          12                             12
#
#    Number_of_months_covered_d
# 0                           0
# 1                          12
# 2                          12

# %%
#Rules Based lableing

w = w.copy()

q = w.quantile([0.75, 0.90, 0.95])
thr_avg_cost_hi  = q.loc[0.90, "avg_reimb"] if "avg_reimb" in w else np.inf
thr_out_ratio_hi = q.loc[0.95, "op_ratio"]   if "op_ratio"   in w else np.inf
thr_car_ratio_hi = q.loc[0.95, "car_ratio"]      if "car_ratio" in w else np.inf
thr_avg_cost_q75 = q.loc[0.75, "avg_reimb"]  if "avg_reimb"  in w else np.inf

rules = pd.DataFrame(index=w.index)
rules["R_high_cost"]        = (w["avg_reimb"] > thr_avg_cost_hi).astype(int)      if "avg_reimb" in w else 0
rules["R_high_out_ratio"]   = (w["op_ratio"]  > thr_out_ratio_hi).astype(int)      if "op_ratio"  in w else 0
rules["R_high_car_ratio"]   = (w["car_ratio"]     > thr_car_ratio_hi).astype(int)      if "car_ratio"     in w else 0
rules["R_high_chronic"]     = (w["chronic_count"]     >= 5).astype(int)                    if "chronic_count"     in w else 0
rules["R_edge_age"]         = ((w["AGE"] <= 5) | (w["AGE"] >= 90)).astype(int)             if "AGE"               in w else 0
rules["R_low_cov_high_cost"]= ((w["total_coverage_months"] <= 3) & (w["avg_reimb"] > thr_avg_cost_q75)).astype(int) \
                               if set(["total_coverage_months","avg_reimb"]).issubset(w.columns) else 0

y_rule = (rules.sum(axis=1) > 0).astype(int)

rules_summary = pd.DataFrame({
    "trigger_rate_%": (rules.mean()*100).round(2),
    "count": rules.sum()
}).sort_values("trigger_rate_%", ascending=False)

y_rule_rate = (y_rule.mean()*100).round(2)
rules_summary, y_rule_rate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 #Rules Based lableing
#       3 w = w.copy()
# ----> 5 q = w.quantile([0.75, 0.90, 0.95])
#       6 thr_avg_cost_hi  = q.loc[0.90, "avg_reimb"] if "avg_reimb" in w else np.inf
#       7 thr_out_ratio_hi = q.loc[0.95, "op_ratio"]   if "op_ratio"   in w else np.inf
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\pandas\core\frame.py:12218, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12214     raise ValueError(
#   12215         f"Invalid method: {method}. Method must be in {valid_method}."
#   12216     )
#   12217 if method == "single":
# > 12218     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12219 elif method == "table":
#   12220     valid_interpolation = {"nearest", "lower", "higher"}
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\pandas\core\internals\managers.py:1568, in BlockManager.quantile(self, qs, interpolation)
#    1564 new_axes = list(self.axes)
#    1565 new_axes[1] = Index(qs, dtype=np.float64)
#    1567 blocks = [
# -> 1568     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1569 ]
#    1571 return type(self)(blocks, new_axes)
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\pandas\core\internals\blocks.py:1957, in Block.quantile(self, qs, interpolation)
#    1954 assert self.ndim == 2
#    1955 assert is_list_like(qs)  # caller is responsible for this
# -> 1957 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1958 # ensure_block_shape needed for cases where we start with EA and result
#    1959 #  is ndarray, e.g. IntegerArray, SparseArray
#    1960 result = ensure_block_shape(result, ndim=2)
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\pandas\core\array_algos\quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\pandas\core\array_algos\quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\pandas\core\array_algos\quantile.py:218, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.percentile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\numpy\lib\_function_base_impl.py:4238, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4235     if np.any(weights < 0):
#    4236         raise ValueError("Weights must be non-negative.")
# -> 4238 return _quantile_unchecked(
#    4239     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\numpy\lib\_function_base_impl.py:4517, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4508 def _quantile_unchecked(a,
#    4509                         q,
#    4510                         axis=None,
#    (...)   4514                         keepdims=False,
#    4515                         weights=None):
#    4516     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4517     return _ureduce(a,
#    4518                     func=_quantile_ureduce_func,
#    4519                     q=q,
#    4520                     weights=weights,
#    4521                     keepdims=keepdims,
#    4522                     axis=axis,
#    4523                     out=out,
#    4524                     overwrite_input=overwrite_input,
#    4525                     method=method)
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\numpy\lib\_function_base_impl.py:3848, in _ureduce(a, func, keepdims, **kwargs)
#    3845             index_out = (0, ) * nd
#    3846             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3848 r = func(a, **kwargs)
#    3850 if out is not None:
#    3851     return out
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\numpy\lib\_function_base_impl.py:4694, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4692         arr = a.copy()
#    4693         wgt = weights
# -> 4694 result = _quantile(arr,
#    4695                    quantiles=q,
#    4696                    axis=axis,
#    4697                    method=method,
#    4698                    out=out,
#    4699                    weights=wgt)
#    4700 return result
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\numpy\lib\_function_base_impl.py:4826, in _quantile(arr, quantiles, axis, method, out, weights)
#    4824         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4825         gamma = gamma.reshape(result_shape)
# -> 4826         result = _lerp(previous,
#    4827                     next,
#    4828                     gamma,
#    4829                     out=out)
#    4830 else:
#    4831     # Weighted case
#    4832     # This implements method="inverted_cdf", the only supported weighted
#    4833     # method, which needs to sort anyway.
#    4834     weights = np.asanyarray(weights)
#
# File c:\Users\payou\anaconda3\envs\claimsai\Lib\site-packages\numpy\lib\_function_base_impl.py:4620, in _lerp(a, b, t, out)
#    4606 def _lerp(a, b, t, out=None):
#    4607     """
#    4608     Compute the linear interpolation weighted by gamma on each point of
#    4609     two same shape array.
#    (...)   4618         Output array.
#    4619     """
# -> 4620     diff_b_a = subtract(b, a)
#    4621     # asanyarray is a stop-gap until gh-13105
#    4622     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
