# %% [markdown]
# # Labeling (Rule-based + Isolation Forest)
#
# **Goal** Create y labels for high-cost detecton:
# -y_rule (transparent, programatic rules)
# -y_iforest (unsupervised labeling approach)
# -y_final (consensus options)
#
# **Input** ../data/preprocessed/beneficiary_features.csv
# **Output** ../data/preprocessed/beneficiary_labeled.csv

# %%
import pandas as pd
import numpy as np

FEATURE_PATH = '../data/processed/beneficiary_features'
df = pd.read_csv(FEATURE_PATH)

print(df.shape)
df.head(3)
df.columns
# Out:
# (349064, 45)
# Index(['Beneficiary Code', 'Birth_date', 'Date_of_Death', 'Gender', 'Race',
#        'End_Stage_Renal_Disease_Indicator', 'State_code', 'County_code',
#        'Number_of_months_covered_a', 'Numver_of_months_covered_b',
#        'Number_of_months_HMO_coverage', 'Number_of_months_covered_d',
#        'Alzhiemers_or_senile', 'Heart_Failure', 'Chronic_Kidney', 'Cancer',
#        'COPD', 'Depression', 'Diabetes', 'ischemic_Heart_Disease',
#        'Osteoporosis', 'Rheumatoid_Arthritis', 'Stroke', 'IP_reimbursement',
#        'IP_Bene_Amount', 'IP_primary_payer_reimbursement',
#        'OP_medicare_reimbursement', 'OP_bene_resp_amount', 'OP_primary',
#        'Carrier_medicare_reimb', 'Carrier_bene_amount',
#        'Carrier_annual_payer_reimb', 'AGE', 'total_reimbursement',
#        'total_beneficiary_amount', 'total_primary_payment',
#        'total_coverage_months', 'chronic_count', 'avg_reimb', 'op_ratio',
# ...

# %%
#Columns needed for labeling

needed = [
    'AGE','Date_of_Death', 'Gender', 'Race', 'total_coverage_months', 'chronic_count',
    'avg_reimb', 'op_ratio','car_ratio', 'Number_of_months_covered_a', 'Numver_of_months_covered_b',
       'Number_of_months_HMO_coverage', 'Number_of_months_covered_d',
]

present = [c for c in needed if c in df.columns]
w = df[present].copy()

#Clean ratios/numerics
for c in ["avg_reimb", "op_ratio", "car_ratio"]:
    if c in w:
        w[c] = pd.to_numeric(w[c], errors="coerce").replace([np.inf, -np.inf], np.nan)

for c in w.select_dtypes(include=[np.number]).columns:
    w[c] = w[c].fillna(w[c].median())

w.head(3)
# Out:
#    AGE  Date_of_Death  Gender      Race  total_coverage_months  chronic_count  \
# 0   51              0  Female  Hispanic                     24             13
# 1   51              0  Female     White                     36             15
# 2   51              0    Male     White                     48             13
#
#      avg_reimb  op_ratio  car_ratio  Number_of_months_covered_a  \
# 0  3551.200000  0.018765   0.075859                          12
# 1   509.459459  0.132720   0.254976                          12
# 2   798.775510  0.002667   0.040956                          12
#
#    Numver_of_months_covered_b  Number_of_months_HMO_coverage  \
# 0                          12                              0
# 1                          12                              0
# 2                          12                             12
#
#    Number_of_months_covered_d
# 0                           0
# 1                          12
# 2                          12

# %%
#Rules Based lableing

import numpy as np
import pandas as pd

# columns you actually use in the rules
cols_needed = ["avg_reimb", "op_ratio", "chronic_count"]  # add any others you reference below

# 1) Force these columns to numeric (coerce invalids to NaN)
for c in cols_needed:
    if c in w.columns:
        w[c] = pd.to_numeric(w[c], errors="coerce")

# 2) Compute quantiles on numeric columns only
num_cols = w.select_dtypes(include="number").columns
q = w[num_cols].quantile([0.75, 0.90, 0.95])  # numeric-only because we filtered

# 3) Safe helpers to read thresholds/series even if a column is missing
def thr(col, level):
    return q.loc[level, col] if (col in q.columns) else np.inf

def col(s):
    return w[s] if (s in w.columns) else np.nan

# %%
#Isolation Forest (Algorithmic Labeling)

from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import IsolationForest

num_cols = w.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = [c for c in ["Gender","Race"] if c in w.columns]

pre = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_cols)
    ],
    remainder="drop"
)

contamination = 0.03  # target anomaly rate; tweak if needed
iforest = Pipeline(steps=[
    ("prep", pre),
    ("clf", IsolationForest(
        n_estimators=300,
        contamination=contamination,
        random_state=42,
        n_jobs=-1
    ))
])

iforest.fit(w)
Xtr = iforest.named_steps["prep"].transform(w)
scores = iforest.named_steps["clf"].decision_function(Xtr)   # higher = more normal
preds  = iforest.named_steps["clf"].predict(Xtr)             # -1=anomaly, 1=normal
y_iforest = (preds == -1).astype(int)

float(y_iforest.mean()*100)
# Out:
# 3.000022918433296

# %%
#Compare and Build consensus labels

# Build rule columns (each returns 0/1; NaN comparisons naturally yield False)
rules = pd.DataFrame(index=w.index)

# High normalized cost: > 90th pct of avg_reimb
rules["R_high_cost"] = (col("avg_reimb") > thr("avg_reimb", 0.90)).astype(int)

# High outpatient skew: > 95th pct of op_ratio
rules["R_high_out_ratio"] = (col("op_ratio") > thr("op_ratio", 0.95)).astype(int)

#High Chronic Illness Rate
rules["R_high_chronic"] = (col("chronic_count") > thr("chronic_count", 0.95)).astype(int)

# Combine to a single rule-based label
y_rule = (rules.sum(axis=1) > 0).astype(int)

# Quick summary
rules_summary = pd.DataFrame({
    "trigger_rate_%": (rules.mean() * 100).round(2),
    "count": rules.sum()
}).sort_values("trigger_rate_%", ascending=False)

y_rule_rate = (y_rule.mean() * 100).round(2)

display(rules_summary)
print("Overall y_rule rate (%):", y_rule_rate)
# Out:
#                   trigger_rate_%  count
# R_high_cost                10.00  34905
# R_high_out_ratio            4.99  17424
# R_high_chronic              0.00      0
# Overall y_rule rate (%): 14.3

# %%
# 5️⃣ Create target variable (is_anomaly)
w["is_anomaly"] = (
    (w["avg_reimb"] > rules["R_high_cost"]) |
    (w["op_ratio"] > rules["R_high_out_ratio"])
).astype(int)

# Optional: sanity check
print(w["is_anomaly"].value_counts(normalize=True))
# Out:
# is_anomaly
# 1    0.737286
# 0    0.262714
# Name: proportion, dtype: float64

# %%
#Save labeled dataset

from pathlib import Path

# 1) Build the labeled frame (copy the working view)
labeled = w.copy()
labeled["y_rule"] = y_rule

# (Optional) keep rule columns with a clear prefix so you can inspect later
rules_prefixed = rules.add_prefix("rule_")
labeled = pd.concat([labeled, rules_prefixed], axis=1)

# 2) Save labeled dataset
out_path = Path("../data/processed/beneficiary_labeled.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)
labeled.to_csv(out_path, index=False)

# 3) Save a separate rules audit (small & scannable)
audit = rules.copy()
audit["y_rule"] = y_rule
audit_path = Path("../data/processed/label_rules_audit.csv")
audit.to_csv(audit_path, index=False)

print("Saved:")
print(" -", out_path.resolve())
print(" -", audit_path.resolve())
print("Shape:", labeled.shape)
# Out:
# Saved:
#  - C:\Users\payou\ClaimsAI\data\processed\beneficiary_labeled.csv
#  - C:\Users\payou\ClaimsAI\data\processed\label_rules_audit.csv
# Shape: (349064, 18)

# %%
#Sanity Checks

def present(colname): 
    return colname in labeled.columns

# 1) Are rule-positive rows actually more expensive?
if present("avg_reimb"):
    display(labeled.groupby("y_rule")["avg_reimb"].describe().round(2))
else:
    print("avg_reimb not present — skipping cost distribution check.")

# 2) Medians by class for interpretability (only prints those that exist)
cols_to_check = ["avg_reimb", "op_ratio", "chronic_count", "age", "total_coverage_mons"]
for c in cols_to_check:
    if present(c):
        med = labeled.groupby("y_rule")[c].median().round(2).to_dict()
        print(f"{c} medians by y_rule:", med)

# 3) Equity slices if demographics available
if present("Gender"):
    print("\nCounts by Race x y_rule")
    display(labeled.groupby(["Race","y_rule"]).size().unstack(fill_value=0))

if present("Race"):
    print("\nCounts by Race x y_rule")
    display(labeled.groupby(["Race","y_rule"]).size().unstack(fill_value=0))

# 4) Quick peek at top rule-positives by cost (if both exist)
if present("y_rule") and present("avg_reimb"):
    print("\nTop rule-positives by avg_reimb:")
    display(labeled.loc[labeled["y_rule"]==1].sort_values("avg_reimb", ascending=False).head(10))
# Out:
#            count    mean      std    min     25%    50%     75%        max
# y_rule
# 0       299163.0   42.84    60.69 -60.00    0.00   19.6   58.82     314.32
# 1        49901.0  714.72  1668.71  47.35  225.95  449.8  802.00  115800.00
# avg_reimb medians by y_rule: {0: 19.6, 1: 449.8}
# op_ratio medians by y_rule: {0: 0.0, 1: 0.18}
# chronic_count medians by y_rule: {0: 21.0, 1: 17.0}
#
# Counts by Race x y_rule
# y_rule         0      1
# Race
# Black      31897   5071
# Hispanic    7258    957
# Other      13050   1495
# White     246958  42378
# Counts by Race x y_rule
# y_rule         0      1
# Race
# Black      31897   5071
# Hispanic    7258    957
# Other      13050   1495
# White     246958  42378
# Top rule-positives by avg_reimb:
#         AGE  Date_of_Death  Gender   Race  total_coverage_months  \
# 262052   51              0  Female  White                      0
# 130455   51              0  Female  White                      0
# ...

# %%
#Check which rules have the most impact

rules_summary.sort_values("trigger_rate_%", ascending=False)
# Out:
#                   trigger_rate_%  count
# R_high_cost                10.00  34905
# R_high_out_ratio            4.99  17424
# R_high_chronic              0.00      0
